# %%
import pandas as pd 

samples = pd.read_json('/raid/work/giubaldini/fhirformer/2018-2023-v1/ds_readmission/sampled/test.jsonl', lines=True)

# %%
# take random sample
samples = samples.sample(n=1)

# %%
print(samples['text'].values[0])
# Out:
# Patient metadata:
# age	5
# gender	male
# insurance_type	gesetzlich
#
# Encounter:
# Beginn	2020-06-02 10:51:00
# Kontakt Art	Einrichtungskontakt
# Art	ambulatory
# Fachabteilungsschlüssel	Pädiatrie/Schwerpunkt Nephrologie
# Aufnahmeanlass	None
#
# ICD Version: 2018
#
# Patient history:
# 2020-06-30 condition: E27.4, Hypoaldosteronismus onA
# 2020-06-19 diagnostic_report:
# 2020-06-18 service_request: 22x Laboratory procedure
# 2020-06-18 observation: FMetHb, 0.3, %; cK+, 4.9, mmol/l; FO2Hb, 91.4, %; ctO2, 15.0, Vol %; cHCO3-(P,st), 23.2, mmol/l; pCO2, 35.7, mm Hg; Temperatur, 37.0, °C; pH, 7.413; sO2, 92.4, %; FHHb, 7.5, %; cLac, 1.6, mmol/l; cCa++, 1.27, mmol/l; FCOHb, 0.8, %; pO2, 58.1, mmHg; cCl-, 110.0, mmol/l; cNa+, 141.0, mmol/l; cGlu, 98.0, mg/dl; ctHb, 11.7, g/dl; cBase(Ecf), -1.6, mmol/l; p50, 23.3, mm Hg
# 2020-06-15 diagnostic_report: Arztbrief, Sammelvorlage Endo
# 2020-06-05 diagnostic_report: Sonstiges Arztbriefe
# 2020-06-02 service_request: 121x Laboratory procedure
# ...
